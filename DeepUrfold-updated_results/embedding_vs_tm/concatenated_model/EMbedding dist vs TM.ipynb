# %%
import pandas as pd 
struct_distances = pd.read_csv("../comparison/tmalign/all_distances.csv")

# %%
struct_distances
# Out:
#          Unnamed: 0                   chain1             chain2  rmsd  \
# 0                 0  /data/1xmkA00.pdb.noter  4co8A00.pdb.noter  3.08
# 1                 1  /data/1xmkA00.pdb.noter  3iwfB00.pdb.noter  3.35
# 2                 2  /data/1xmkA00.pdb.noter  1r7jA00.pdb.noter  2.60
# 3                 3  /data/1xmkA00.pdb.noter  2fq3A00.pdb.noter  2.32
# 4                 4  /data/1xmkA00.pdb.noter  5it3A00.pdb.noter  2.32
# ...             ...                      ...                ...   ...
# 6239273           1  /data/2a9dA01.pdb.noter  2biiA01.pdb.noter  1.54
# 6239274           2  /data/2a9dA01.pdb.noter  1xdyG00.pdb.noter  2.59
# 6239275           0  /data/2blfA01.pdb.noter  2biiA01.pdb.noter  2.11
# 6239276           1  /data/2blfA01.pdb.noter  1xdyG00.pdb.noter  3.17
# 6239277           0  /data/2biiA01.pdb.noter  1xdyG00.pdb.noter  2.80
#
#          moving_tm_score  fixed_tm_score
# 0                0.55923         0.47596
# 1                0.48692         0.45279
# 2                0.62223         0.56055
# 3                0.54607         0.51675
# 4                0.55082         0.52018
# ...                  ...             ...
# 6239273          0.85861         0.89345
# 6239274          0.63389         0.60041
# 6239275          0.78134         0.85279
# 6239276          0.63448         0.63002
# 6239277          0.67397         0.61419
#
# [6239278 rows x 6 columns]

# %%
struct_distances["chain1"] = struct_distances["chain1"].apply(lambda s: s.split("/")[-1].split(".")[0])
struct_distances["chain2"] = struct_distances["chain2"].apply(lambda s: s.split(".")[0])
struct_distances
# Out:
#          Unnamed: 0   chain1   chain2  rmsd  moving_tm_score  fixed_tm_score
# 0                 0  1xmkA00  4co8A00  3.08          0.55923         0.47596
# 1                 1  1xmkA00  3iwfB00  3.35          0.48692         0.45279
# 2                 2  1xmkA00  1r7jA00  2.60          0.62223         0.56055
# 3                 3  1xmkA00  2fq3A00  2.32          0.54607         0.51675
# 4                 4  1xmkA00  5it3A00  2.32          0.55082         0.52018
# ...             ...      ...      ...   ...              ...             ...
# 6239273           1  2a9dA01  2biiA01  1.54          0.85861         0.89345
# 6239274           2  2a9dA01  1xdyG00  2.59          0.63389         0.60041
# 6239275           0  2blfA01  2biiA01  2.11          0.78134         0.85279
# 6239276           1  2blfA01  1xdyG00  3.17          0.63448         0.63002
# 6239277           0  2biiA01  1xdyG00  2.80          0.67397         0.61419
#
# [6239278 rows x 6 columns]

# %%
UMAP = False
if UMAP:
    raw_latent = pd.read_hdf("COSINESIM--cosine-umap-all_latent.h5", "table")
else:
    raw_latent = pd.read_hdf("COSINESIM--cosine-umap-all.h5", "table")

# %%
if raw_latent.shape[1]==4:
    raw_latent = raw_latent.drop(columns=["ss_score", "electrostatics"])

# %%
raw_latent
# Out:
#                         0_1.10.10.10  1_1.10.10.10  2_1.10.10.10  \
# cathDomain superfamily
# 1xmkA00    1.10.10.10       0.008947     -0.006150     -0.000019
# 4co8A00    1.10.10.10       0.014225     -0.014322      0.015423
# 3iwfB00    1.10.10.10      -0.006005      0.010001      0.011174
# 1r7jA00    1.10.10.10       0.012556      0.009071      0.009244
# 2fq3A00    1.10.10.10       0.001257     -0.002225      0.005614
# ...                              ...           ...           ...
# 2a9dA01    3.90.420.10      0.008457      0.011480     -0.000237
# 2blfA01    3.90.420.10     -0.018430      0.013825     -0.001666
# 5k3xB01    3.90.420.10     -0.015403      0.005477      0.004809
# 2biiA01    3.90.420.10      0.020082     -0.010060     -0.000397
# 1xdyG00    3.90.420.10      0.016779      0.037610     -0.085829
#
#                         3_1.10.10.10  4_1.10.10.10  5_1.10.10.10  \
# cathDomain superfamily
# 1xmkA00    1.10.10.10      -0.000234      0.001549      0.008561
# 4co8A00    1.10.10.10      -0.003182     -0.016237     -0.019064
# 3iwfB00    1.10.10.10      -0.010232     -0.009428     -0.003086
# 1r7jA00    1.10.10.10       0.013257      0.005269     -0.010077
# 2fq3A00    1.10.10.10      -0.020798      0.007141      0.018810
# ...                              ...           ...           ...
# 2a9dA01    3.90.420.10      0.003556     -0.001234     -0.026494
# 2blfA01    3.90.420.10     -0.010240     -0.022255      0.006122
# 5k3xB01    3.90.420.10     -0.007786      0.011095     -0.005543
# 2biiA01    3.90.420.10     -0.010027      0.002777     -0.004358
# 1xdyG00    3.90.420.10      0.131132      0.031221     -0.132836
#
#                         6_1.10.10.10  7_1.10.10.10  8_1.10.10.10  \
# cathDomain superfamily
# 1xmkA00    1.10.10.10       0.015258      0.010154     -0.004361
# 4co8A00    1.10.10.10       0.001850     -0.010428      0.030222
# 3iwfB00    1.10.10.10      -0.005161      0.008899     -0.015502
# 1r7jA00    1.10.10.10      -0.024007     -0.014470      0.012991
# 2fq3A00    1.10.10.10       0.012784     -0.001029      0.014980
# ...                              ...           ...           ...
# 2a9dA01    3.90.420.10      0.043376     -0.005820     -0.008860
# 2blfA01    3.90.420.10      0.003566      0.003204     -0.008511
# 5k3xB01    3.90.420.10     -0.021046      0.026083     -0.008080
# 2biiA01    3.90.420.10      0.009620      0.017487     -0.021712
# 1xdyG00    3.90.420.10      0.000194      0.040238     -0.116662
#
#                         9_1.10.10.10  ...  1014_3.90.420.10  1015_3.90.420.10  \
# cathDomain superfamily                ...
# 1xmkA00    1.10.10.10      -0.013709  ...          0.101689          0.199236
# 4co8A00    1.10.10.10       0.023604  ...          0.007561          0.226484
# 3iwfB00    1.10.10.10       0.002808  ...          0.059672          0.225709
# 1r7jA00    1.10.10.10      -0.001201  ...          0.108041          0.193962
# 2fq3A00    1.10.10.10      -0.006659  ...          0.049020          0.156001
# ...                              ...  ...               ...               ...
# 2a9dA01    3.90.420.10      0.006011  ...          0.074337          0.113865
# 2blfA01    3.90.420.10     -0.020046  ...          0.149284          0.079784
# 5k3xB01    3.90.420.10     -0.009268  ...          0.095506          0.071230
# 2biiA01    3.90.420.10     -0.017401  ...          0.070426          0.084538
# 1xdyG00    3.90.420.10      0.066134  ...         -0.128961         -0.041082
#
#                         1016_3.90.420.10  1017_3.90.420.10  1018_3.90.420.10  \
# cathDomain superfamily
# 1xmkA00    1.10.10.10           0.001478          0.068457          0.018073
# 4co8A00    1.10.10.10           0.004382          0.137492         -0.002096
# 3iwfB00    1.10.10.10           0.041441          0.130005          0.008178
# 1r7jA00    1.10.10.10          -0.013615          0.051033          0.045130
# 2fq3A00    1.10.10.10           0.068142          0.126206          0.057143
# ...                                  ...               ...               ...
# 2a9dA01    3.90.420.10          0.059787         -0.067903         -0.002690
# 2blfA01    3.90.420.10         -0.073683          0.173083         -0.118353
# 5k3xB01    3.90.420.10         -0.151052          0.180539          0.011729
# 2biiA01    3.90.420.10         -0.033835          0.041517         -0.045258
# 1xdyG00    3.90.420.10          0.063214          0.092858          0.019629
#
#                         1019_3.90.420.10  1020_3.90.420.10  1021_3.90.420.10  \
# cathDomain superfamily
# 1xmkA00    1.10.10.10          -0.073577          0.010957          0.026463
# 4co8A00    1.10.10.10          -0.115950         -0.066924          0.087758
# 3iwfB00    1.10.10.10          -0.055750         -0.031388          0.017539
# 1r7jA00    1.10.10.10          -0.032121          0.034770         -0.048382
# 2fq3A00    1.10.10.10          -0.051694         -0.051545         -0.000972
# ...                                  ...               ...               ...
# 2a9dA01    3.90.420.10         -0.079642         -0.020740          0.043176
# 2blfA01    3.90.420.10         -0.115714         -0.027459          0.056203
# 5k3xB01    3.90.420.10          0.001544         -0.028129          0.068009
# 2biiA01    3.90.420.10         -0.132033         -0.050061         -0.010874
# 1xdyG00    3.90.420.10         -0.121229         -0.183620          0.403747
#
#                         1022_3.90.420.10  1023_3.90.420.10
# cathDomain superfamily
# 1xmkA00    1.10.10.10           0.114034          0.021565
# 4co8A00    1.10.10.10          -0.011905          0.025842
# 3iwfB00    1.10.10.10           0.077446         -0.028042
# 1r7jA00    1.10.10.10          -0.036015         -0.030811
# 2fq3A00    1.10.10.10           0.037756         -0.051934
# ...                                  ...               ...
# 2a9dA01    3.90.420.10          0.100068         -0.049539
# 2blfA01    3.90.420.10         -0.015943          0.031518
# 5k3xB01    3.90.420.10          0.129816         -0.089900
# 2biiA01    3.90.420.10          0.114980         -0.122339
# 1xdyG00    3.90.420.10          0.032324         -0.099915
#
# [3674 rows x 20480 columns]

# %%
from sklearn.metrics import pairwise_distances

# %%
raw_latent_dist = pairwise_distances(raw_latent.values, metric="cosine")

# %%
domains = raw_latent.reset_index().cathDomain
raw_latent_dist_pd = pd.DataFrame(raw_latent_dist, index=domains, columns=domains)

# %%
raw_latent_dist_pd
# Out:
# cathDomain   1xmkA00   4co8A00   3iwfB00   1r7jA00   2fq3A00   5it3A00  \
# cathDomain
# 1xmkA00     0.000000  0.573580  0.564257  0.597911  0.606925  0.567555
# 4co8A00     0.573580  0.000000  0.529215  0.503413  0.593511  0.478353
# 3iwfB00     0.564257  0.529215  0.000000  0.537889  0.613625  0.483125
# 1r7jA00     0.597911  0.503413  0.537889  0.000000  0.587674  0.508489
# 2fq3A00     0.606925  0.593511  0.613625  0.587674  0.000000  0.579758
# ...              ...       ...       ...       ...       ...       ...
# 2a9dA01     0.813200  0.866054  0.815540  0.837627  0.824675  0.869347
# 2blfA01     0.785689  0.803240  0.758977  0.799793  0.756818  0.797353
# 5k3xB01     0.620609  0.620081  0.600957  0.604137  0.638982  0.613290
# 2biiA01     0.780689  0.767725  0.752839  0.772454  0.754810  0.797406
# 1xdyG00     0.919168  0.947501  0.958554  0.934228  0.925543  0.963215
#
# cathDomain   5hdkC00   1i27A00   1s29A00   6el8A00  ...   3j7ye00   1f3yA00  \
# cathDomain                                          ...
# 1xmkA00     0.569502  0.589144  0.584467  0.578453  ...  0.746739  0.935254
# 4co8A00     0.477281  0.546489  0.513595  0.475525  ...  0.784526  0.969077
# 3iwfB00     0.492413  0.563887  0.481743  0.470563  ...  0.766371  0.958555
# 1r7jA00     0.495761  0.592059  0.538555  0.503909  ...  0.778097  0.957607
# 2fq3A00     0.592560  0.610344  0.574976  0.585668  ...  0.779840  0.957509
# ...              ...       ...       ...       ...  ...       ...       ...
# 2a9dA01     0.866398  0.840950  0.848732  0.810789  ...  0.769539  0.835535
# 2blfA01     0.795112  0.777969  0.806590  0.784316  ...  0.731782  0.830249
# 5k3xB01     0.592867  0.644934  0.607059  0.589805  ...  0.800254  0.939951
# 2biiA01     0.775177  0.783043  0.784729  0.768166  ...  0.776667  0.863588
# 1xdyG00     0.931743  0.907316  0.981167  0.934272  ...  0.852727  0.630579
#
# cathDomain   1x51A01   1vw4601   2xtsA01   2a9dA01   2blfA01   5k3xB01  \
# cathDomain
# 1xmkA00     0.924590  0.710406  0.769132  0.813200  0.785689  0.620609
# 4co8A00     0.939514  0.741015  0.831888  0.866054  0.803240  0.620081
# 3iwfB00     0.936645  0.743447  0.820813  0.815540  0.758977  0.600957
# 1r7jA00     0.904810  0.728933  0.825965  0.837627  0.799793  0.604137
# 2fq3A00     0.902883  0.710881  0.770728  0.824675  0.756818  0.638982
# ...              ...       ...       ...       ...       ...       ...
# 2a9dA01     0.849389  0.806235  0.733760  0.000000  0.778460  0.812024
# 2blfA01     0.838669  0.785361  0.755485  0.778460  0.000000  0.769432
# 5k3xB01     0.926698  0.732068  0.784711  0.812024  0.769432  0.000000
# 2biiA01     0.838510  0.788273  0.745519  0.772018  0.801244  0.767719
# 1xdyG00     0.592199  0.919734  0.866222  0.825234  0.876357  0.957335
#
# cathDomain   2biiA01   1xdyG00
# cathDomain
# 1xmkA00     0.780689  0.919168
# 4co8A00     0.767725  0.947501
# 3iwfB00     0.752839  0.958554
# 1r7jA00     0.772454  0.934228
# 2fq3A00     0.754810  0.925543
# ...              ...       ...
# 2a9dA01     0.772018  0.825234
# 2blfA01     0.801244  0.876357
# 5k3xB01     0.767719  0.957335
# 2biiA01     0.000000  0.866933
# 1xdyG00     0.866933  0.000000
#
# [3674 rows x 3674 columns]

# %%
raw_latent_dist_pd.reset_index().melt(id_vars="cathDomain", var_name="chain2", value_name="Embedding Distance").rename(columns={"cathDomain":"chain1"})
# Out:
#            chain1   chain2  Embedding Distance
# 0         1xmkA00  1xmkA00            0.000000
# 1         4co8A00  1xmkA00            0.573580
# 2         3iwfB00  1xmkA00            0.564257
# 3         1r7jA00  1xmkA00            0.597911
# 4         2fq3A00  1xmkA00            0.606925
# ...           ...      ...                 ...
# 13498271  2a9dA01  1xdyG00            0.825234
# 13498272  2blfA01  1xdyG00            0.876357
# 13498273  5k3xB01  1xdyG00            0.957335
# 13498274  2biiA01  1xdyG00            0.866933
# 13498275  1xdyG00  1xdyG00            0.000000
#
# [13498276 rows x 3 columns]

# %%
6239278>13498276
# Out:
# False

# %%
6239278*2+len(raw_latent_dist_pd.index)
# Out:
# 12482230

# %%
import numpy as np

# %%
raw_latent_dist_masked = raw_latent_dist.copy()
raw_latent_dist_masked[np.triu_indices(raw_latent_dist.shape[0], k = 1)] = -1
raw_latent_dist_masked
# Out:
# array([[ 0.        , -1.        , -1.        , ..., -1.        ,
#         -1.        , -1.        ],
#        [ 0.57358024,  0.        , -1.        , ..., -1.        ,
#         -1.        , -1.        ],
#        [ 0.56425662,  0.52921475,  0.        , ..., -1.        ,
#         -1.        , -1.        ],
#        ...,
#        [ 0.62060879,  0.62008074,  0.60095723, ...,  0.        ,
#         -1.        , -1.        ],
#        [ 0.78068905,  0.7677251 ,  0.75283891, ...,  0.76771853,
#          0.        , -1.        ],
#        [ 0.91916809,  0.94750081,  0.95855411, ...,  0.95733473,
#          0.866933  ,  0.        ]])

# %%
raw_latent_dist_masked_pd = pd.DataFrame(raw_latent_dist_masked, index=domains, columns=domains)

# %%
raw_latent_dist_masked_pd = raw_latent_dist_masked_pd.reset_index().melt(id_vars="cathDomain", var_name="chain2", value_name="Embedding Distance").rename(columns={"cathDomain":"chain1"})

# %%
raw_latent_dist_masked_pd
# Out:
#            chain1   chain2  Embedding Distance
# 0         1xmkA00  1xmkA00            0.000000
# 1         4co8A00  1xmkA00            0.573580
# 2         3iwfB00  1xmkA00            0.564257
# 3         1r7jA00  1xmkA00            0.597911
# 4         2fq3A00  1xmkA00            0.606925
# ...           ...      ...                 ...
# 13498271  2a9dA01  1xdyG00           -1.000000
# 13498272  2blfA01  1xdyG00           -1.000000
# 13498273  5k3xB01  1xdyG00           -1.000000
# 13498274  2biiA01  1xdyG00           -1.000000
# 13498275  1xdyG00  1xdyG00            0.000000
#
# [13498276 rows x 3 columns]

# %%
raw_latent_dist_masked_pd2 = raw_latent_dist_masked_pd[raw_latent_dist_masked_pd["Embedding Distance"]>0]

# %%
raw_latent_dist_masked_pd2
# Out:
#            chain1   chain2  Embedding Distance
# 1         4co8A00  1xmkA00            0.573580
# 2         3iwfB00  1xmkA00            0.564257
# 3         1r7jA00  1xmkA00            0.597911
# 4         2fq3A00  1xmkA00            0.606925
# 5         5it3A00  1xmkA00            0.567555
# ...           ...      ...                 ...
# 13487252  2biiA01  2blfA01            0.801244
# 13487253  1xdyG00  2blfA01            0.876357
# 13490926  2biiA01  5k3xB01            0.767719
# 13490927  1xdyG00  5k3xB01            0.957335
# 13494601  1xdyG00  2biiA01            0.866933
#
# [6747301 rows x 3 columns]

# %%
raw_latent_dist_masked_pd3 = pd.merge(raw_latent_dist_masked_pd2, struct_distances, on=["chain1", "chain2"])

# %%
raw_latent_dist_masked_pd3
# Out:
#       chain1   chain2  Embedding Distance  Unnamed: 0  rmsd  moving_tm_score  \
# 0    5lohA02  4nfnA02            0.851013           0  2.87          0.76997
# 1    5lohA02  4aaaA02            0.741420           1  2.03          0.83242
# 2    5lohA02  2izrA02            0.630301           2  2.92          0.77170
# 3    4i92A02  2a2aA02            0.768766           0  3.10          0.67950
# 4    5lohA02  2a2aA02            0.558971           4  2.57          0.82089
# ..       ...      ...                 ...         ...   ...              ...
# 465  1wicA01  1wfnA01            0.641485           1  3.04          0.47173
# 466  1va9A00  2cuhA01            0.670947           3  2.22          0.58153
# 467  1wicA01  2cuhA01            0.713123           2  3.19          0.47811
# 468  2dmbA00  2dleA01            0.689195           0  2.77          0.46984
# 469  1gxeA00  1b4rA00            0.731988           0  3.26          0.42869
#
#      fixed_tm_score
# 0           0.67520
# 1           0.73922
# 2           0.64648
# 3           0.63879
# 4           0.70626
# ..              ...
# 465         0.60118
# 466         0.75739
# 467         0.60213
# 468         0.61365
# 469         0.61228
#
# [470 rows x 7 columns]

# %%
struct_distances2 = struct_distances.copy()
struct_distances2 = struct_distances2.rename(columns={"chain1":"chain2_"}).rename(
    columns={"chain2":"chain1", "chain2_":"chain2"})

# %%
raw_latent_dist_masked_pd3_5 = pd.merge(raw_latent_dist_masked_pd2, struct_distances2, on=["chain1", "chain2"])

# %%
raw_latent_dist_masked_pd3_5
# Out:
#           chain1   chain2  Embedding Distance  Unnamed: 0  rmsd  \
# 0        4co8A00  1xmkA00            0.573580           0  3.08
# 1        3iwfB00  1xmkA00            0.564257           1  3.35
# 2        1r7jA00  1xmkA00            0.597911           2  2.60
# 3        2fq3A00  1xmkA00            0.606925           3  2.32
# 4        5it3A00  1xmkA00            0.567555           4  2.32
# ...          ...      ...                 ...         ...   ...
# 5615801  2biiA01  2a9dA01            0.772018           1  1.54
# 5615802  1xdyG00  2a9dA01            0.825234           2  2.59
# 5615803  2biiA01  2blfA01            0.801244           0  2.11
# 5615804  1xdyG00  2blfA01            0.876357           1  3.17
# 5615805  1xdyG00  2biiA01            0.866933           0  2.80
#
#          moving_tm_score  fixed_tm_score
# 0                0.55923         0.47596
# 1                0.48692         0.45279
# 2                0.62223         0.56055
# 3                0.54607         0.51675
# 4                0.55082         0.52018
# ...                  ...             ...
# 5615801          0.85861         0.89345
# 5615802          0.63389         0.60041
# 5615803          0.78134         0.85279
# 5615804          0.63448         0.63002
# 5615805          0.67397         0.61419
#
# [5615806 rows x 7 columns]

# %%
raw_latent_dist_masked_pd3 = pd.concat((raw_latent_dist_masked_pd3, raw_latent_dist_masked_pd3_5))

# %%
raw_latent_dist_masked_pd3
# Out:
#           chain1   chain2  Embedding Distance  Unnamed: 0  rmsd  \
# 0        5lohA02  4nfnA02            0.851013           0  2.87
# 1        5lohA02  4aaaA02            0.741420           1  2.03
# 2        5lohA02  2izrA02            0.630301           2  2.92
# 3        4i92A02  2a2aA02            0.768766           0  3.10
# 4        5lohA02  2a2aA02            0.558971           4  2.57
# ...          ...      ...                 ...         ...   ...
# 5615801  2biiA01  2a9dA01            0.772018           1  1.54
# 5615802  1xdyG00  2a9dA01            0.825234           2  2.59
# 5615803  2biiA01  2blfA01            0.801244           0  2.11
# 5615804  1xdyG00  2blfA01            0.876357           1  3.17
# 5615805  1xdyG00  2biiA01            0.866933           0  2.80
#
#          moving_tm_score  fixed_tm_score
# 0                0.76997         0.67520
# 1                0.83242         0.73922
# 2                0.77170         0.64648
# 3                0.67950         0.63879
# 4                0.82089         0.70626
# ...                  ...             ...
# 5615801          0.85861         0.89345
# 5615802          0.63389         0.60041
# 5615803          0.78134         0.85279
# 5615804          0.63448         0.63002
# 5615805          0.67397         0.61419
#
# [5616276 rows x 7 columns]

# %%
import seaborn as sns

# %%
def get_similarity_groupings(tm):
    if tm<=0.3:
        return "Random Similarity"
    elif 0.3<tm<=0.5:
        return "Similar Architecture"
    else:
        return "Likely Similar Fold"
    

raw_latent_dist_masked_pd3 = raw_latent_dist_masked_pd3.assign(
    Similarity=raw_latent_dist_masked_pd3.moving_tm_score.apply(get_similarity_groupings))

# %%
raw_latent_dist_masked_pd3
# Out:
#           chain1   chain2  Embedding Distance  Unnamed: 0  rmsd  \
# 0        5lohA02  4nfnA02            0.851013           0  2.87
# 1        5lohA02  4aaaA02            0.741420           1  2.03
# 2        5lohA02  2izrA02            0.630301           2  2.92
# 3        4i92A02  2a2aA02            0.768766           0  3.10
# 4        5lohA02  2a2aA02            0.558971           4  2.57
# ...          ...      ...                 ...         ...   ...
# 5615801  2biiA01  2a9dA01            0.772018           1  1.54
# 5615802  1xdyG00  2a9dA01            0.825234           2  2.59
# 5615803  2biiA01  2blfA01            0.801244           0  2.11
# 5615804  1xdyG00  2blfA01            0.876357           1  3.17
# 5615805  1xdyG00  2biiA01            0.866933           0  2.80
#
#          moving_tm_score  fixed_tm_score           Similarity
# 0                0.76997         0.67520  Likely Similar Fold
# 1                0.83242         0.73922  Likely Similar Fold
# 2                0.77170         0.64648  Likely Similar Fold
# 3                0.67950         0.63879  Likely Similar Fold
# 4                0.82089         0.70626  Likely Similar Fold
# ...                  ...             ...                  ...
# 5615801          0.85861         0.89345  Likely Similar Fold
# 5615802          0.63389         0.60041  Likely Similar Fold
# 5615803          0.78134         0.85279  Likely Similar Fold
# 5615804          0.63448         0.63002  Likely Similar Fold
# 5615805          0.67397         0.61419  Likely Similar Fold
#
# [5616276 rows x 8 columns]

# %%
raw_latent_dist_masked_pd3 = raw_latent_dist_masked_pd3.assign(
    **{"1/(Raw Embedding Distance)^2":1/(raw_latent_dist_masked_pd3["Embedding Distance"]**2)}
)

# %%
viridis = sns.color_palette("viridis", as_cmap=True)
color_pallete = sns.color_palette(viridis([0, 0.5, 1]))

# %%
import matplotlib.pyplot as plt
sample = raw_latent_dist_masked_pd3.sample(10000)
fig, ax = plt.subplots()

sns.regplot(data=sample, 
    x="moving_tm_score", y="Embedding Distance",scatter=False, color="#808080")#, hue="Similarity")
sns.scatterplot(data=sample, 
    x="moving_tm_score", y="Embedding Distance", hue="Similarity", ax=ax, 
    hue_order=["Random Similarity", "Similar Architecture", "Likely Similar Fold"],
    palette=color_pallete)
plt.xlabel("TM-Score")
if raw_latent.shape[1] == 2:
    plt.ylabel("2D UMAP Embedding Cosine Distance")
    name = "2D_UMAP_Embedding_Cosine_Distance"
else:
    plt.ylabel(f"Raw {raw_latent.shape[1]}-Embedding Cosine Distance")
    name = f"Raw_{raw_latent.shape[1]}-Embedding_Cosine_Distance"
plt.savefig(f"Concatenated_Distance_plot_{name}.pdf", dpi=600, bbox_inches="tight")
plt.savefig(f"Concatenated_Distance_plot_{name}.pdf", dpi=600, bbox_inches="tight")

# %%
raw_latent_dist_masked_pd3["1/(Raw Embedding Distance)^2"].max()
# Out:
# 14.30613957059755

# %%
sns.kdeplot(data=raw_latent_dist_masked_pd3, x="Embedding Distance", hue="Similarity")
# Out:
# <Axes: xlabel='Embedding Distance', ylabel='Density'>
